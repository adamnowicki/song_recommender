# %%
import pandas as pd
from time import sleep
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import pickle

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

# %%
track_search = "Lose yourself"
artist_search="Eminem"

# %%
results = sp.search(q=f"artist:{artist_search} track:{track_search}",limit=3)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3AEminem+track%3ALose+yourself&type=track&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
# ...

# %%
data = []
for track in results['tracks']['items']:
    artists = ', '.join(artist['name'] for artist in track['artists'])
    song_name = track['name']
    track_id = track['id']
    data.append({'Artist': artists, 'Song': song_name, 'Track ID': track_id})

# Create DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#    Artist           Song                Track ID
# 0  Eminem  Lose Yourself  5Z01UMMf7V1o0MzF86s6WJ
# 1  Eminem  Lose Yourself  77Ft1RJngppZlq59B6uP0z
# 2  Eminem  Lose Yourself  2jvHb9SHJDi8Ugky7tUzUb

# %%
track_id = '5Z01UMMf7V1o0MzF86s6WJ'
song=sp.audio_features(track_id)
song
# Out:
# [{'danceability': 0.692,
#   'energy': 0.744,
#   'key': 2,
#   'loudness': -4.565,
#   'mode': 1,
#   'speechiness': 0.257,
#   'acousticness': 0.00868,
#   'instrumentalness': 0.000423,
#   'liveness': 0.359,
#   'valence': 0.0612,
#   'tempo': 171.374,
#   'type': 'audio_features',
#   'id': '5Z01UMMf7V1o0MzF86s6WJ',
#   'uri': 'spotify:track:5Z01UMMf7V1o0MzF86s6WJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Z01UMMf7V1o0MzF86s6WJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Z01UMMf7V1o0MzF86s6WJ',
#   'duration_ms': 326467,
#   'time_signature': 4}]

# %%
song_expl=sp.track(track_id)['explicit']
song_pop = sp.track(track_id)['popularity']

# %%
song_df= pd.DataFrame(song)

# %%
song_df['is_explicit']=song_expl
song_df['popularity']=song_pop
song_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.692   0.744    2    -4.565     1        0.257       0.00868
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000423     0.359   0.0612  171.374  audio_features
#
#                        id                                   uri  \
# 0  5Z01UMMf7V1o0MzF86s6WJ  spotify:track:5Z01UMMf7V1o0MzF86s6WJ
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5Z01UMMf7V1o...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5Z01...       326467
#
#    time_signature  is_explicit  popularity
# 0               4         True          78

# %%
selected_columns = ['is_explicit','popularity','danceability', 'energy', 'key', 
                    'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
                    'liveness', 'valence', 'tempo', 'time_signature']
song_df = song_df[selected_columns]
song_df
# Out:
#    is_explicit  popularity  danceability  energy  key  loudness  mode  \
# 0         True          78         0.692   0.744    2    -4.565     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.257       0.00868          0.000423     0.359   0.0612  171.374
#
#    time_signature
# 0               4

# %%
with open('km100.pickle', 'rb') as handle:
    km100 = pickle.load(handle)

with open('scaler.pickle', 'rb') as handle:
    scaler = pickle.load(handle)

# %%
scaled_song = scaler.fit_transform(song_df)
km100.predict(scaled_song)
# Out:
# array([61], dtype=int32)

# %%
clusters_df= pd.read_csv("tracks_clustered_df.csv")

# %%
km100
# Out:
# KMeans(n_clusters=100)
